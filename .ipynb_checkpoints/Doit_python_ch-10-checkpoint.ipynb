# %% [markdown]
# # Ch-10. 텍스트 마이닝
# ## 10-1. 대통령 연설문 텍스트 마이닝

# %% [markdown]
# ### - (p.279) KoNLPy 패키지 설치

# %%
# 1. JAVA and JDK 설치
## - (web) Install Amazon Corretto from abit.ly/easypy_101
## - (web) Install JDK from https://www.oracle.com/kr/java/technologies/downloads/

# %%
# 2. KoNLPy 패키지 설치 
## - (cmd) pip install jpype1
## - (cmd) pip install konlpy

# %%
# 3. wordcloud 패키지 설치
## - (cmd) pip install wordcloud

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import konlpy
from wordcloud import WordCloud
import PIL
import os

# %%
os.chdir('C:\\Users\\James\\Documents\\GitHub\\Doit_Python\\Data')
os.getcwd()
# Out:
# 'C:\\Users\\James\\Documents\\GitHub\\Doit_Python\\Data'

# %% [markdown]
# ### - (p.280) 가장 많이 사용된 단어 알아보기

# %% [markdown]
# #### (1) 연설문 불러오기

# %%
moon = open('speech_moon.txt', encoding = 'UTF-8').read()
moon
# Out:
# '정권교체 하겠습니다!\n  정치교체 하겠습니다!\n  시대교체 하겠습니다!\n  \n  ‘불비불명(不飛不鳴)’이라는 고사가 있습니다. 남쪽 언덕 나뭇가지에 앉아, 3년 동안 날지도 울지도 않는 새. 그러나 그 새는 한번 날면 하늘 끝까지 날고, 한번 울면 천지를 뒤흔듭니다.\n\n그 동안 정치와 거리를 둬 왔습니다. 그러나 암울한 시대가 저를 정치로 불러냈습니다. 더 이상 남쪽 나뭇가지에 머무를 수 없었습니다. 이제 저는 국민과 함께 높이 날고 크게 울겠습니다. 오늘 저는 제18대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다.\n\n\n‘우리나라 대통령’이 되겠습니다.\n\n\n존경하는 국민 여러분!\n  \n  저는 대통령이 되겠습니다. 우리나라 대통령이 되겠습니다. 소수 특권층의 나라가 아니라 보통사람들이 주인인 ‘우리나라’, 네 편 내 편 편가르지 않고 함께 가는 우리나라, ‘우리’라는 말이 조금도 부끄럽지 않은, 진정한 ‘우리나라’의 대통령이 되겠습니다.\n\n지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다. 나라의 주인으로 행세하지 못했고, 주인으로 대접받지 못했습니다. 나서서 말도 하지 못했습니다. 이제 몸을 일으켜 날아야 합니다. 당당하게 말하고 정치에 참여해야 합니다.\n\n제가 추구하는 ‘우리나라’는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다. 저는 시민과 동행하는 정치를 하고 싶습니다. 제가 추구하는 ‘우리나라’는 특권과 불평등의 나라가 아니라, 보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다.\n\n이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다. 힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제, 낡은 정치, 낡은 권력도 모두 끝났습니다. 오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다.\n\n국민이 모두 아픕니다.\n\n제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고, 우리가 처한 현실이 너무도 
# ...

# %% [markdown]
# #### (2) 불필요한 문자 제거 (공백으로 변경)

# %%
import re

# %% [markdown]
# ##### * [^가-힣] : 한글이 아닌 모든 문자

# %%
moon = re.sub('[^가-힣]', ' ', moon)
moon
# Out:
# '정권교체 하겠습니다    정치교체 하겠습니다    시대교체 하겠습니다        불비불명       이라는 고사가 있습니다  남쪽 언덕 나뭇가지에 앉아   년 동안 날지도 울지도 않는 새  그러나 그 새는 한번 날면 하늘 끝까지 날고  한번 울면 천지를 뒤흔듭니다   그 동안 정치와 거리를 둬 왔습니다  그러나 암울한 시대가 저를 정치로 불러냈습니다  더 이상 남쪽 나뭇가지에 머무를 수 없었습니다  이제 저는 국민과 함께 높이 날고 크게 울겠습니다  오늘 저는 제  대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다     우리나라 대통령 이 되겠습니다    존경하는 국민 여러분       저는 대통령이 되겠습니다  우리나라 대통령이 되겠습니다  소수 특권층의 나라가 아니라 보통사람들이 주인인  우리나라   네 편 내 편 편가르지 않고 함께 가는 우리나라   우리 라는 말이 조금도 부끄럽지 않은  진정한  우리나라 의 대통령이 되겠습니다   지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다  나라의 주인으로 행세하지 못했고  주인으로 대접받지 못했습니다  나서서 말도 하지 못했습니다  이제 몸을 일으켜 날아야 합니다  당당하게 말하고 정치에 참여해야 합니다   제가 추구하는  우리나라 는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다  저는 시민과 동행하는 정치를 하고 싶습니다  제가 추구하는  우리나라 는 특권과 불평등의 나라가 아니라  보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다   이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다  힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제  낡은 정치  낡은 권력도 모두 끝났습니다  오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다   국민이 모두 아픕니다   제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고  우리가 처한 현실이 너무도 엄중하기 때문입니다  근본적인 혁신  거대한
# ...

# %% [markdown]
# #### (3) 명사 추출

# %%
import konlpy

# %%
hannanum = konlpy.tag.Hannanum()

# %%
# 명사 추출 예시
hannanum.nouns("대한민국의 영토는 한반도와 그 부속도서로 한다")
# Out:
# ['대한민국', '영토', '한반도', '부속도서']

# %%
nouns = hannanum.nouns(moon)

# %%
nouns[:5]
# Out:
# ['정권교체', '정치교체', '시대교체', '불비불명', '고사']

# %% [markdown]
# #### (4) 데이터 프레임으로 변환

# %%
df_word = pd.DataFrame({'word' : nouns})

# %%
df_word.head()
# Out:
#    word
# 0  정권교체
# 1  정치교체
# 2  시대교체
# 3  불비불명
# 4    고사

# %% [markdown]
# #### (5) 단어 빈도표 만들기

# %%
# 글자수 추가
df_word['count'] = df_word['word'].str.len()

# %%
df_word.head()
# Out:
#    word  count
# 0  정권교체      4
# 1  정치교체      4
# 2  시대교체      4
# 3  불비불명      4
# 4    고사      2

# %% [markdown]
# #### (6) 두 글자 이상 단어만 남기기

# %%
df_word = df_word.query('count >= 2')
df_word.sort_values('count')
# Out:
#           word  count
# 712         국민      2
# 1164        가사      2
# 1163        숙제      2
# 1162        평등      2
# 644         확대      2
# ...        ...    ...
# 707     평생학습체제      6
# 1268    군사대결지대      6
# 173     성적스트레스      6
# 978   고용영향평가제도      8
# 1055  국가일자리위원회      8
#
# [1187 rows x 2 columns]

# %% [markdown]
# #### (7) 단어 빈도 구하기

# %%
df_word = df_word.groupby('word', as_index = False) \
                 .agg(n = ('word', 'count')) \
                 .sort_values('n', ascending = False)
df_word.head()
# Out:
#     word   n
# 153   나라  19
# 462  일자리  19
# 116   국민  18
# 422   우리  17
# 198  대통령  12

# %%
# 상위 20개 추출
top20 = df_word.head(20)
top20
# Out:
#      word   n
# 153    나라  19
# 462   일자리  19
# 116    국민  18
# 422    우리  17
# 198   대통령  12
# 202  대한민국  11
# 693    확대  11
# 525    정치  10
# 423  우리나라  10
# 304    사회   9
# 298    사람   9
# 332    성장   9
# 646    평화   8
# 266  복지국가   8
# 265    복지   8
# 308    산업   7
# 517    정부   7
# 609    추진   7
# 103    교육   6
# 339    세상   6

# %% [markdown]
# #### (8) 빈도표 그리기

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 한글폰트 설정
plt.rcParams.update({'font.family'    : 'Malgun Gothic',
                     'figure.dpi'     : '120',
                     'figure.figsize' : [5, 5]})

# %%
sns.barplot(data=top20, y='word', x='n');

# %% [markdown]
# ### - (p.286) 워드 클라우드 만들기

# %% [markdown]
# #### (1) wordcloud 패키지 설치

# %%
# (cmd) pip install wordcloud

# %%
# wordcloud 설치 시 오류 발생하면,
# --> Microsoft Visual C++ 설치 from bit.ly/easypy_103
# --> 설치화면 왼쪽 위 'C++를 사용한 데스크톱 개발' 체크 후 install

# %% [markdown]
# #### (2) 한글폰트 설정

# %%
font = 'DoHyeon-Regular.ttf'

# %%
df_word.head()
# Out:
#     word   n
# 153   나라  19
# 462  일자리  19
# 116   국민  18
# 422   우리  17
# 198  대통령  12

# %% [markdown]
# #### (3) 단어와 빈도를 담은 딕셔너리 만들기

# %%
dic_word = df_word.set_index('word').to_dict()['n']

# %% [markdown]
# #### (4) 워드 클라우드

# %%
from wordcloud import WordCloud

# %% [markdown]
# ##### * wc 만들기

# %%
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white')

# %% [markdown]
# ##### * wc.generate_from_frequencies(dict)

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

# %% [markdown]
# ##### * 워드 클라우드 출력

# %%
plt.figure(figsize = (5, 5))     # 가로, 세로 크기 설정
plt.axis('off')                  # 테두리 선 없애기
plt.imshow(img_wordcloud);       # 워드 클라우드 출력

# %% [markdown]
# ### - (p.289) 클래스를 이용해 인스턴스 만들기

# %% [markdown]
# #### (1) 클래스

# %%
# 클래스(Class): 메서드와 어트리뷰트를 가지고 있는 변수
# ex) konlpy.tag.Hannanum 
# ex) WordCloud()

# %% [markdown]
# #### (2) 인스턴스

# %%
# 인스턴스(instance): 클래스로 만든 변수
# hannanum = konlpy.tag.Hannanum
# wc = WordCloud(random_state=1234, ..., )

# %%
from wordcloud import WordCloud
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white')

img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (5, 5))
plt.axis('off')
plt.imshow(img_wordcloud);

# %% [markdown]
# ### - (p.289) 워드 클라우드 모양 바꾸기

# %% [markdown]
# #### (1) mask 만들기

# %%
import PIL

# %%
icon = PIL.Image.open('cloud.png')
icon
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=825x467>

# %%
icon.size
# Out:
# (825, 467)

# %%
import numpy as np

# %%
img = PIL.Image.new('RGB', icon.size, (255, 255, 255))
img
# Out:
# <PIL.Image.Image image mode=RGB size=825x467>

# %%
img.paste(icon, icon)
img
# Out:
# <PIL.Image.Image image mode=RGB size=825x467>

# %%
img = np.array(img)
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# #### (2) 워드 클라우드 만들기

# %%
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white',
               mask = img)

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (5, 5))
plt.axis('off')
plt.imshow(img_wordcloud);

# %% [markdown]
# ### - (p.291) 워드 클라우드 색깔 바꾸기(colormap)

# %%
# Choosing Colormaps in Matplotlib: bit.ly/easypy_104

# %%
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white',
               mask = img,
               colormap = 'inferno')

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (7, 7))
plt.axis('off')
plt.imshow(img_wordcloud);

# %% [markdown]
# ## 10-2. 기사 댓글 텍스트 마이닝
# ### - (p.293) 가장 많이 사용된 단어 알아보기
# #### (1) 기사 댓글 불러오기

# %%
df = pd.read_csv('news_comment_BTS.csv', encoding = 'UTF-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   reg_time  1200 non-null   object
#  1   reply     1200 non-null   object
#  2   press     1200 non-null   object
#  3   title     1200 non-null   object
#  4   url       1200 non-null   object
# dtypes: object(5)
# memory usage: 47.0+ KB

# %% [markdown]
# #### (2) 불필요한 문자 제거하기

# %%
df['reply'] = df['reply'].str.replace('[^가-힣]', ' ', regex = True)
df['reply'].head()
# Out:
# 0                                    국보소년단
# 1                                         아줌마가 들어도 좋더라
# 2    팩트체크    현재 빌보드             위  방탄소년단        위  ...
# 3              방탄소년단이 한국사람이라 너무 자랑스러워요    우리오래오래 함께하자
# 4                  대단한      월드 클래스는 다르네   좋은 소식   응원해요
# Name: reply, dtype: object

# %% [markdown]
# #### (3) 명사 추출하기 - 꼬꼬마 형태소 분석기

# %%
import konlpy

# %%
kkma = konlpy.tag.Kkma()

# %%
# 데이터프레임 --> apply 적용
nouns = df['reply'].apply(kkma.nouns)
nouns
# Out:
# 0                                        [국보, 국보소년단, 소년단]
# 1                                                   [아줌마]
# 2                   [팩트, 팩트체크, 체크, 보드, 위, 방탄, 방탄소년단, 소년단]
# 3              [방탄, 방탄소년단, 소년단, 한국, 한국사람, 사람, 자랑, 우리, 하자]
# 4                                       [월드, 클래스, 소식, 응원]
#                               ...
# 1195                                                   []
# 1196                                      [우리, 탄, 자랑, 사랑]
# 1197                                              [애, 군대]
# 1198                                     [군, 군면제급, 면제, 급]
# 1199    [자랑, 축하, 김, 김남, 남, 김석진, 민, 민윤기, 윤기, 정, 정호석, 호석...
# Name: reply, Length: 1200, dtype: object

# %% [markdown]
# #### (4) 단어 빈도표 만들기

# %% [markdown]
# ##### * explode()

# %%
# 한 행에 한 단어만 들어가도록 구성
nouns = nouns.explode()
nouns
# Out:
# 0          국보
# 0       국보소년단
# 0         소년단
# 1         아줌마
# 2          팩트
#         ...
# 1199      박지민
# 1199      김태형
# 1199        전
# 1199      전정국
# 1199       정국
# Name: reply, Length: 9353, dtype: object

# %%
# 데이터프레임으로 변환
df_word = pd.DataFrame({'word' : nouns})
df_word['count'] = df_word['word'].str.len()
df_word = df_word.query('count >= 2')

# %%
df_word.head()
# Out:
#     word  count
# 0     국보    2.0
# 0  국보소년단    5.0
# 0    소년단    3.0
# 1    아줌마    3.0
# 2     팩트    2.0

# %%
df_word = df_word.groupby('word', as_index = False) \
                 .agg(n = ('word', 'count')) \
                 .sort_values('n', ascending = False)

# %%
df_word.head()
# Out:
#        word    n
# 752      방탄  280
# 1878     축하  236
# 1556     자랑  205
# 1032    소년단  144
# 763   방탄소년단  136

# %%
top20 = df_word.head(20)

# %% [markdown]
# #### (5) 단어 빈도 막대그래프

# %%
plt.rcParams.update({'figure.figsize' : [5, 5],
                     'figure.dpi': '120',
                     'font.family' : 'Malgun Gothic'})

# %%
sns.barplot(data = top20, y = 'word', x = 'n');

# %% [markdown]
# ### - (p.298) 워드 클라우드 만들기

# %% [markdown]
# #### (1) df -> dict 로 변환

# %%
dic_word = df_word.set_index('word').to_dict()['n']

# %% [markdown]
# #### (2) wc

# %%
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white',
               mask = img)

# %% [markdown]
# #### (3) 워드 클라우드

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (5, 5))
plt.axis('off')
plt.imshow(img_wordcloud);

# %% [markdown]
# ## - End.

# %% [markdown]
# ## [Practice] ------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import PIL
import konlpy
from wordcloud import WordCloud
import os

# %%
os.chdir('C:\\Users\\James\\Documents\\GitHub\\Doit_Python\\Data')
os.getcwd()
# Out:
# 'C:\\Users\\James\\Documents\\GitHub\\Doit_Python\\Data'

# %%
moon = open('speech_moon.txt', encoding = 'UTF-8').read()

# %%
import re

# %%
moon = re.sub('[^가-힣]', ' ', moon)

# %%
hannanum = konlpy.tag.Hannanum()

# %%
nouns = hannanum.nouns(moon)

# %%
df_word = pd.DataFrame({'word' : nouns})

# %%
df_word['count'] = df_word['word'].str.len()

# %%
df_word = df_word.query('count >= 2')

# %%
df_word['count'].value_counts()
# Out:
# 2    756
# 3    204
# 4    178
# 5     34
# 6     13
# 8      2
# Name: count, dtype: int64

# %%
df_word.sort_values('count')

# %%
df_word = df_word.groupby('word', as_index = False).agg(n = ('word', 'count')).sort_values('n', ascending = False)

# %%
top20 = df_word.head(20)

# %%
plt.rcParams.update({'font.family'    : 'Malgun Gothic',
                     'figure.dpi'     : '120',
                     'figure.figsize' : [6.5, 6]})

# %%
sns.barplot(data=top20, y='word', x='n');

# %%
font = 'DoHyeon-Regular.ttf'

# %%
dic_word = df_word.set_index('word').to_dict()['n']

# %%
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white')

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

# %%
plt.figure(figsize = (5, 5))
plt.axis('off')
plt.imshow(img_wordcloud);

# %%
cloud_icon = PIL.Image.open('cloud.png')

# %%
cloud_img = PIL.Image.new('RGB', cloud_icon.size, (255, 255, 255))
cloud_img.paste(cloud_icon, cloud_icon)
cloud_img = np.array(cloud_img)

# %%
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white',
               mask = cloud_img)

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

# %%
plt.figure(figsize = (5, 5))
plt.axis('off')
plt.imshow(img_wordcloud);

# %%
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white',
               mask = cloud_img,
               colormap = 'inferno')

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

# %%
plt.figure(figsize = (5, 5))
plt.axis('off')
plt.imshow(img_wordcloud);

# %%
df = pd.read_csv('news_comment_BTS.csv', encoding = 'UTF-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   reg_time  1200 non-null   object
#  1   reply     1200 non-null   object
#  2   press     1200 non-null   object
#  3   title     1200 non-null   object
#  4   url       1200 non-null   object
# dtypes: object(5)
# memory usage: 47.0+ KB

# %%
df.head(3)
# Out:
#               reg_time                                              reply  \
# 0  2020-09-01 22:58:09                                  국보소년단<U+0001F49C>
# 1  2020-09-01 09:56:46                                       아줌마가 들어도 좋더라
# 2  2020-09-01 09:08:06  팩트체크\r\n\r\n현재 빌보드 HOT 100\r\n\r\n1위  방탄소년단[BT...
#
#   press                                  title  \
# 0  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 1  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 2  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
#
#                                                  url
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df['reply'] = df['reply'].str.replace('[^가-힣]', ' ', regex = True)

# %%
df['reply'].head()
# Out:
# 0                                    국보소년단
# 1                                         아줌마가 들어도 좋더라
# 2    팩트체크    현재 빌보드             위  방탄소년단        위  ...
# 3              방탄소년단이 한국사람이라 너무 자랑스러워요    우리오래오래 함께하자
# 4                  대단한      월드 클래스는 다르네   좋은 소식   응원해요
# Name: reply, dtype: object

# %%
kkma = konlpy.tag.Kkma()

# %%
nouns = df['reply'].apply(kkma.nouns)

# %%
nouns
# Out:
# 0                                        [국보, 국보소년단, 소년단]
# 1                                                   [아줌마]
# 2                   [팩트, 팩트체크, 체크, 보드, 위, 방탄, 방탄소년단, 소년단]
# 3              [방탄, 방탄소년단, 소년단, 한국, 한국사람, 사람, 자랑, 우리, 하자]
# 4                                       [월드, 클래스, 소식, 응원]
#                               ...
# 1195                                                   []
# 1196                                      [우리, 탄, 자랑, 사랑]
# 1197                                              [애, 군대]
# 1198                                     [군, 군면제급, 면제, 급]
# 1199    [자랑, 축하, 김, 김남, 남, 김석진, 민, 민윤기, 윤기, 정, 정호석, 호석...
# Name: reply, Length: 1200, dtype: object

# %%
nouns = nouns.explode()
nouns
# Out:
# 0          국보
# 0       국보소년단
# 0         소년단
# 1         아줌마
# 2          팩트
#         ...
# 1199      박지민
# 1199      김태형
# 1199        전
# 1199      전정국
# 1199       정국
# Name: reply, Length: 9353, dtype: object

# %%
df_word = pd.DataFrame({'word' : nouns})
df_word['count'] = df_word['word'].str.len()
df_word = df_word.query('count >= 2')
df_word = df_word.groupby('word', as_index = False).agg(n = ('word', 'count')).sort_values('n', ascending = False)
df_word
# Out:
#        word    n
# 752      방탄  280
# 1878     축하  236
# 1556     자랑  205
# 1032    소년단  144
# 763   방탄소년단  136
# ...     ...  ...
# 1136   실력있음    1
# 406    다음주면    1
# 1134     신화    1
# 1133     신중    1
# 1084    스을적    1
#
# [2168 rows x 2 columns]

# %%
top20 = df_word.head(20)

# %%
plt.rcParams.update({'figure.figsize' : [6.5, 6]})

# %%
sns.barplot(data=top20, y='word', x='n');

# %%
dic_word = df_word.set_index('word').to_dict()['n']

# %%
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white',
               mask = cloud_img,
               colormap = 'inferno')

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

# %%
plt.figure(figsize = (5, 5))
plt.axis('off')
plt.imshow(img_wordcloud);
